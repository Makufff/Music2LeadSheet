# %% [markdown]
# # Introduction to Music2leadsheet

# %% [markdown]
# # Setup Library

# %%
import os
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
from librosa.effects import harmonic
from collections import Counter
from music21 import note , duration , environment

# %% [markdown]
# # Setup Environment

# %%
us = environment.UserSettings()
us['musicxmlPath'] = r'C://Program Files//MuseScore 4//bin//MuseScore4.exe'
us['musescoreDirectPNGPath'] = r'C://Program Files//MuseScore 4//bin//MuseScore4.exe'
us['lilypondPath'] = r'C://Music2leadsheet//lilypond-2.24.3//bin//lilypond.exe'

# %% [markdown]
# # Separate vocals
# * แยกเสียงร้องออกจากเพลง

# %%
filename = input().replace("\\" , "/")
print(filename)
os.system(f"demucs -d cpu {filename}")
# Out:
# C:/Music2leadsheet/TEST.wav
# 0

# %% [markdown]
# # Notes
# * อ่านไฟล์เสียง
# * เอาเสียงร้องที่มาแยกเป็นแปลเป็น Note โดย ใช้ความยาวของเสียงจุดเริ่มต้นของเสียงร้องถึงจุดสิ้นสุดเสียงเป็น 1 โน๊ต
# * ต้องการเอาเสียงของโน๊ต(pitch) โดยเอาช่วงเวลามาทำของแต่ละโน๊ตมาทำ Fourier analysis โดยใช้ Fast Fourier Transform (time domain to frequency domain)โดยเลือก frequency ที่มากที่สุดเพื่อไปพยากรณ์ว่าเป็นโน๊ตตัวใด
#
# ```python
# data_structure = {
# "Duration": float ,
# "Note": string
# }
# ```

# %% [markdown]
# # Onset

# %% [markdown]
# # Fix Duration

# %%
import librosa
import numpy as np

# Function to perform Fourier analysis and find dominant frequency
def get_dom_freq(signal, sr):
    # Calculate FFT
    fft = np.fft.fft(signal)
    # Frequency corresponding to each point in FFT
    freqs = np.fft.fftfreq(len(fft), 1/sr)
    # Find index of maximum amplitude in FFT
    dom_freq_index = np.argmax(np.abs(fft))
    # Get dominant frequency
    dom_freq = freqs[dom_freq_index]
    return dom_freq

# Data structure for storing notes
data_structure = []

# Define note frequencies
note_frequencies = {
    "A3": 220.0,
    "A#3": 233.1,
    "B3": 246.9,
    "C4": 261.6,
    "C#4": 277.2,
    "D4": 293.7,
    "D#4": 311.1,
    "E4": 329.6,
    "F4": 349.2,
    "F#4": 370.0,
    "G4": 392.0,
    "G#4": 415.3,
    "A4": 440.0
}

# Load audio file
file_path = r'C:\Music2leadsheet\separated\htdemucs\TEST\vocals.wav'  # Replace with your audio file path
audio_data, sr = librosa.load(file_path, sr=None)

# Find onset times using the spectrogram
onset_frames = librosa.onset.onset_detect(y=audio_data, sr=sr)

# Convert onset frames to times
onset_times = librosa.frames_to_time(onset_frames, sr=sr)

# Iterate through onsets to get note durations
for i in range(len(onset_times) - 1):
    start = int(onset_times[i] * sr)
    end = int(onset_times[i + 1] * sr)
    segment = audio_data[start:end]

    # Perform Fourier analysis to find dominant frequency
    dominant_freq = get_dom_freq(segment, sr)

    # Find the closest note based on dominant frequency
    closest_note = min(note_frequencies, key=lambda x: abs(note_frequencies[x] - dominant_freq))

    # Calculate duration in quarterLength
    duration_in_quarters = onset_times[i + 1] - onset_times[i]

    # Add data to the data structure
time': 8.185034013605442, 'end_time': 8.301133786848073, 'duration': 0.11609977324263099, 'note': 'A3'}, {'start_time': 8.301133786848073, 'end_time': 8.347573696145124, 'duration': 0.04643990929705133, 'note': 'A4'}, {'start_time': 8.347573696145124, 'end_time': 8.870022675736962, 'duration': 0.5224489795918377, 'note': 'A4'}, {'start_time': 8.870022675736962, 'end_time': 9.102222222222222, 'duration': 0.2321995464852602, 'note': 'A4'}, {'start_time': 9.102222222222222, 'end_time': 9.357641723356009, 'duration': 0.25541950113378675, 'note': 'A4'}, {'start_time': 9.357641723356009, 'end_time': 9.496961451247165, 'duration': 0.13931972789115576, 'note': 'A4'}, {'start_time': 9.496961451247165, 'end_time': 9.659501133786849, 'duration': 0.1625396825396841, 'note': 'G#4'}, {'start_time': 9.659501133786849, 'end_time': 9.763990929705216, 'duration': 0.10448979591836682, 'note': 'G#4'}, {'start_time': 9.763990929705216, 'end_time': 9.798820861678005, 'duration': 0.03482993197278894, 'note': 'A3'}, {'start_time': 9.798820861678005, 'end_time': 9.891700680272109, 'duration': 0.09287981859410444, 'note': 'G4'}, {'start_time': 9.891700680272109, 'end ...

# %% [markdown]
# # Generate a random

# %%
from music21 import note, stream, metadata, environment

# Function to convert note names to music21 Note objects
def create_note(note_name):
    return note.Note(note_name)

# Function to generate a music sheet using music21
def generate_music_sheet(data_structure, title= " Generated Music Sheet "):
    # Create an empty music21 Stream
    music_stream = stream.Stream()

    # Set title for the music sheet
    music_sheet_metadata = metadata.Metadata()
    music_sheet_metadata.title = title
    music_stream.insert(0, music_sheet_metadata)

    for segment in data_structure:
        # Extract duration and note information
        duration = segment['duration']
        note_name = segment['note']

        # Create a Note object based on the note name
        n = create_note(note_name)
        # Set the duration of the note
        n.duration.quarterLength = duration
        # Add the note to the music stream
        music_stream.append(n)

    return music_stream

# Generate music sheet with a title
sheet_title = "My Generated Music Sheet"  # Replace with your desired title
music_sheet = generate_music_sheet(data_structure, title=sheet_title)

# Show the music sheet with notes displayed
env = environment.Environment()
music_sheet.show()
# Out:
# ---------------------------------------------------------------------------
# MusicXMLExportException                   Traceback (most recent call last)
# c:\Music2leadsheet\music2sheet.ipynb Cell 13 line 3
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X13sZmlsZQ%3D%3D?line=34'>35</a> # Show the music sheet with notes displayed
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X13sZmlsZQ%3D%3D?line=35'>36</a> env = environment.Environment()
# ---> <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X13sZmlsZQ%3D%3D?line=36'>37</a> music_sheet.show()
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\stream\base.py:412, in Stream.show(self, fmt, app, **keywords)
#     410 if self.isSorted is False and self.autoSort:
#     411     self.sort()
# --> 412 return super().show(fmt=fmt, app=app, **keywords)
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\base.py:2960, in Music21Object.show(self, fmt, app, **keywords)
#    2958 scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2959 formatWriter = scClass()
# -> 2960 return formatWriter.show(self,
#    2961                          regularizedConverterFormat,
#    2962                          app=app,
#    2963                          subformats=subformats,
#    2964                          **keywords)
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\converter\subConverters.py:383, in ConverterIPython.show(self, obj, fmt, app, subformats, **keywords)
#     380 helperSubConverter = Converter.getSubConverterFromFormat(helperFormat)
#     382 if helperFormat in ('musicxml', 'xml', 'lilypond', 'lily'):
# --> 383     ip21_converters.showImageThroughMuseScore(
#     384         obj,
#     385         subConverter=helperSubConverter,
#     386         fmt=helperFormat,
#     387         subformats=helperSubformats,
#     388         **keywords,
#     389     )
#     390 elif helperFormat == 'midi':
#     391     if t.TYPE_CHECKING:
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\ipython21\converters.py:80, in showImageThroughMuseScore(obj, subConverter, fmt, subformats, multipageWidget, **keywords)
#      70         showImageThroughMuseScore(
#      71             s,
#      72             subConverter=subConverter,
#    (...)
#      76             **keywords,
#      77         )
#      78     return
# ---> 80 fp = subConverter.write(
#      81     obj,
#      82     fmt,
#      83     subformats=subformats,
#      84     trimEdges=not multipageWidget,
#      85     **keywords,
#      86 )
#      88 if subformats[0] != 'png':
#      89     return
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\converter\subConverters.py:974, in ConverterMusicXML.write(self, obj, fmt, fp, subformats, makeNotation, compress, **keywords)
#     972 generalExporter = m21ToXml.GeneralObjectExporter(obj)
#     973 generalExporter.makeNotation = makeNotation
# --> 974 dataBytes = generalExporter.parse()
#     976 writeDataStreamFp = fp
#     977 if fp is not None and subformats:  # could be empty list
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:449, in GeneralObjectExporter.parse(self, obj)
#     447 if self.makeNotation:
#     448     outObj = self.fromGeneralObject(obj)
# --> 449     return self.parseWellformedObject(outObj)
#     450 else:
#     451     if not isinstance(obj, stream.Score):
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:465, in GeneralObjectExporter.parseWellformedObject(self, sc)
#     456 '''
#     457 Parse an object that has already gone through the
#     458 `.fromGeneralObject` conversion, which has produced a copy with
#    (...)
#     462 Returns bytes.
#     463 '''
#     464 scoreExporter = ScoreExporter(sc, makeNotation=self.makeNotation)
# --> 465 scoreExporter.parse()
#     466 return scoreExporter.asBytes()
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:1543, in ScoreExporter.parse(self)
#    1541     self.setPartExporterStaffGroups()
#    1542     self.renumberVoicesWithinStaffGroups()
# -> 1543     self.parsePartlikeScore()
#    1544 else:
#    1545     self.parseFlatScore()
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:1728, in ScoreExporter.parsePartlikeScore(self)
#    1726     self._populatePartExporterList()
#    1727 for part_ex in self.partExporterList:
# -> 1728     part_ex.parse()
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:2782, in PartExporter.parse(self)
#    2780             e.partName = self.stream.partName
#    2781         # else: could be a Score without parts (flat)
# -> 2782         raise e
#    2783     self.xmlRoot.append(mxMeasure)
#    2785 return self.xmlRoot
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:2776, in PartExporter.parse(self)
#    2774 measureExporter.spannerBundle = self.spannerBundle
#    2775 try:
# -> 2776     mxMeasure = measureExporter.parse()
#    2777 except MusicXMLExportException as e:
#    2778     e.measureNumber = str(m.number)
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:3220, in MeasureExporter.parse(self)
#    3218 self.setLeftBarline()
#    3219 # BIG ONE
# -> 3220 self.mainElementsParse()
#    3221 # continue
#    3222 self.setRightBarline()
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:3234, in MeasureExporter.mainElementsParse(self)
#    3230 # need to handle objects in order when creating musicxml
#    3231 # we thus assume that objects are sorted here
#    3233 if not m.hasVoices():
# -> 3234     self.parseFlatElements(m, backupAfterwards=False)
#    3235     return
#    3237 nonVoiceMeasureItems = m.getElementsNotOfClass(stream.Voice).stream()
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:3391, in MeasureExporter.parseFlatElements(self, m, backupAfterwards)
#    3389             self.parseOneElement(n, AppendSpanners.NONE)
#    3390         else:
# -> 3391             self.parseOneElement(n, AppendSpanners.NORMAL)
#    3393 # Second pass: If this flat stream (measure/voice) contains any SpannerAnchors, we
#    3394 # will perform a second pass, emitting any pre/postList for any object that is
#    3395 # functioning as a spanner anchor (the SpannerAnchors, as well as any GeneralNotes
#    (...)
#    3398 # Before second pass, stash off self.offsetInMeasure in case we need to jump forward
#    3399 # to it after the second pass.
#    3400 firstPassEndOffsetInMeasure: OffsetQL = self.offsetInMeasure
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:3477, in MeasureExporter.parseOneElement(self, obj, appendSpanners)
#    3475 meth = getattr(self, methName)
#    3476 for o in objList:
# -> 3477     meth(o)
#    3478 parsedObject = True
#    3479 break
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:4158, in MeasureExporter.noteToXml(self, n, noteIndexInChord, chordParent)
#    4156 else:
#    4157     try:
# -> 4158         mxType.text = typeToMusicXMLType(d.type)
#    4159     except MusicXMLExportException:
#    4160         if isinstance(n, note.Rest) and helpers.isFullMeasureRest(n):
#    4161             # type will be removed in xmlToRest()
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\musicxml\m21ToXml.py:111, in typeToMusicXMLType(value)
#     108     raise MusicXMLExportException(
#     109         'Cannot convert "duplex-maxima" duration to MusicXML (too long).')
#     110 elif value == 'inexpressible':
# --> 111     raise MusicXMLExportException('Cannot convert inexpressible durations to MusicXML.')
#     112 elif value == 'complex':
#     113     raise MusicXMLExportException(
#     114         'Cannot convert complex durations to MusicXML. '
#     115         + 'Try exporting with makeNotation=True or manually running splitAtDurations()')
#
# MusicXMLExportException: In part (None), measure (1): Cannot convert inexpressible durations to MusicXML.

# %%
from music21 import note, stream, metadata, environment


# Function to generate a music sheet using music21
def generate_music_sheet(data_structure, title= " Generated Music Sheet "):
    # Create an empty music21 Stream
    music_stream = stream.Stream()

    # Set title for the music sheet
    music_sheet_metadata = metadata.Metadata()
    music_sheet_metadata.title = title
    music_stream.insert(0, music_sheet_metadata)

    for segment in data_structure:
        # Extract duration and note information
        duration = segment['duration']
        note_name = segment['note']
        print(round(duration,2) , " : " , note_name)
        # Create a Note object based on the note name
        n = note.Note(note_name, quarterLength = round(duration,1))
        # Add the note to the music stream
        music_stream.append(n)

    return music_stream

# Generate music sheet with a title
sheet_title = "My Generated Music Sheet"  # Replace with your desired title
music_sheet = generate_music_sheet(data_structure, title=sheet_title)

# Show the music sheet with notes displayed
music_sheet.show()
# Out:
# 0.24  :  A4
# 0.55  :  A3
# 0.26  :  E4
# 0.27  :  E4
# 0.28  :  D#4
# 0.13  :  C#4
# 0.13  :  A3
# 0.27  :  D#4
# 0.14  :  F4
# 0.12  :  F4
# 0.53  :  A3
# 0.41  :  A4
# 0.12  :  A4
# 0.53  :  A3
# 0.15  :  G4
# 0.12  :  A4
# 0.13  :  F#4
# 0.13  :  F#4
# 0.27  :  F#4
# 0.27  :  E4
# 0.27  :  A4
# 0.52  :  G#4
# 0.13  :  F#4
# 0.14  :  F#4
# 0.41  :  A3
# 0.12  :  A3
# 0.05  :  A4
# 0.52  :  A4
# 0.23  :  A4
# 0.14  :  A3
# 0.15  :  A3
# 0.46  :  A4
# 1.0  :  C#4
# 0.13  :  A3
# 0.1  :  A4
# 0.16  :  A4
# 0.09  :  A4
# 0.15  :  A#3
# 0.36  :  A3
# 0.3  :  F4
# 0.1  :  F4
# 0.03  :  F4
# 0.59  :  A4
# 0.31  :  A3
# 0.03  :  A3
# 0.12  :  A4
# 0.1  :  A4
# 0.19  :  A3
# 0.77  :  G#4
# 0.81  :  A3
# 0.05  :  A4
# 0.08  :  A3
# 0.17  :  A4
# 0.19  :  A4
# 0.38  :  A4
# 0.45  :  A4
# 0.3  :  A4
# 0.75  :  A4
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Music2leadsheet\music2sheet.ipynb Cell 14 line 3
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X14sZmlsZQ%3D%3D?line=27'>28</a> music_sheet = generate_music_sheet(data_structure, title=sheet_title)
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X14sZmlsZQ%3D%3D?line=29'>30</a> # Show the music sheet with notes displayed
# ---> <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X14sZmlsZQ%3D%3D?line=30'>31</a> music_sheet.show()
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\stream\base.py:412, in Stream.show(self, fmt, app, **keywords)
#     410 if self.isSorted is False and self.autoSort:
#     411     self.sort()
# --> 412 return super().show(fmt=fmt, app=app, **keywords)
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\base.py:2960, in Music21Object.show(self, fmt, app, **keywords)
#    2958 scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2959 formatWriter = scClass()
# -> 2960 return formatWriter.show(self,
#    2961                          regularizedConverterFormat,
#    2962                          app=app,
#    2963                          subformats=subformats,
#    2964                          **keywords)
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\converter\subConverters.py:383, in ConverterIPython.show(self, obj, fmt, app, subformats, **keywords)
#     380 helperSubConverter = Converter.getSubConverterFromFormat(helperFormat)
#     382 if helperFormat in ('musicxml', 'xml', 'lilypond', 'lily'):
# --> 383     ip21_converters.showImageThroughMuseScore(
#     384         obj,
#     385         subConverter=helperSubConverter,
#     386         fmt=helperFormat,
#     387         subformats=helperSubformats,
#     388         **keywords,
#     389     )
#     390 elif helperFormat == 'midi':
#     391     if t.TYPE_CHECKING:
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\ipython21\converters.py:80, in showImageThroughMuseScore(obj, subConverter, fmt, subformats, multipageWidget, **keywords)
#      70         showImageThroughMuseScore(
#      71             s,
#      72             subConverter=subConverter,
#    (...)
#      76             **keywords,
#      77         )
#      78     return
# ---> 80 fp = subConverter.write(
#      81     obj,
#      82     fmt,
#      83     subformats=subformats,
#      84     trimEdges=not multipageWidget,
#      85     **keywords,
#      86 )
#      88 if subformats[0] != 'png':
#      89     return
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\converter\subConverters.py:991, in ConverterMusicXML.write(self, obj, fmt, fp, subformats, makeNotation, compress, **keywords)
#     988 if (('png' in subformats or 'pdf' in subformats)
#     989         and not str(environLocal['musescoreDirectPNGPath']).startswith('/skip')):
#     990     from music21.converter.museScore import runThroughMuseScore
# --> 991     outFp = runThroughMuseScore(xmlFp, subformats, **keywords)
#     992 elif compress:
#     993     archiveTools.compressXML(xmlFp,
#     994                              deleteOriginal=True,
#     995                              silent=True,
#     996                              strictMxlCheck=False)
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\converter\museScore.py:87, in runThroughMuseScore(fp, subformats, dpi, trimEdges, leaveMargin, **keywords)
#      84     if dpi is None:
#      85         museScoreRun.extend(['-r', str(defaults.jupyterImageDpi)])
# ---> 87 common.fileTools.runSubprocessCapturingStderr(museScoreRun)
#      89 if common.runningInNotebook() and common.getPlatform() == 'nix':
#      90     # Leave environment in original state
#      91     if prior_qt is None:
#
# File c:\Users\Tanap\AppData\Local\Programs\Python\Python310\lib\site-packages\music21\common\fileTools.py:171, in runSubprocessCapturingStderr(subprocessCommand)
#     168 except UnicodeDecodeError:
#     169     # not really a str, but best we can do.
#     170     stderr_str = stderr_bytes.decode('ascii', errors='ignore')
# --> 171 raise IOError(stderr_str)
#
# OSError:

# %% [markdown]
# # Test

# %%
import os
import librosa
import librosa.display
import numpy as np
import shutil
from music21 import note , stream , metadata , environment

us = environment.UserSettings()
us['musicxmlPath'] = r'C://Program Files//MuseScore 4//bin//MuseScore4.exe'
us['musescoreDirectPNGPath'] = r'C://Program Files//MuseScore 4//bin//MuseScore4.exe'
us['lilypondPath'] = r'C://Music2leadsheet//lilypond-2.24.3//bin//lilypond.exe'

# =================================================================
# DEFINES
# Data structure for storing notes
data_structure = []
# Define note frequencies
note_frequencies = {
    "A3": 220.0,
    "A#3": 233.1,
    "B3": 246.9,
    "C4": 261.6,
    "C#4": 277.2,
    "D4": 293.7,
    "D#4": 311.1,
    "E4": 329.6,
    "F4": 349.2,
    "F#4": 370.0,
    "G4": 392.0,
    "G#4": 415.3,
    "A4": 440.0
}
# =================================================================

# =================================================================
# FUNCTIONS
# Function to perform Fourier analysis and find dominant frequency
def get_dom_freq(signal, sr):
    # Calculate FFT
    fft = np.fft.fft(signal)
    # Frequency corresponding to each point in FFT
    freqs = np.fft.fftfreq(len(fft), 1/sr)
    # Find index of maximum amplitude in FFT
    dom_freq_index = np.argmax(np.abs(fft))
    # Get dominant frequency
    dom_freq = freqs[dom_freq_index]
    return dom_freq

# Function to convert note names to music21 Note objects
def create_note(note_name):
    return note.Note(note_name)

# Function to generate a music sheet using music21
def generate_music_sheet(data_structure, title="Generated Music Sheet"):
    # Create an empty music21 Stream
    music_stream = stream.Stream()

    # Set title for the music sheet
    music_sheet_metadata = metadata.Metadata()
    music_sheet_metadata.title = title
    music_stream.insert(0, music_sheet_metadata)

    for segment in data_structure:
        # Extract duration and note information
        duration = segment['duration']
        note_name = segment['note']

        # Create a Note object based on the note name
        n = create_note(note_name)
        # Set the duration of the note
        n.duration.quarterLength = duration
        # Add the note to the music stream
        music_stream.append(n)

    return music_stream
# =================================================================

# =================================================================

# config
filename = input().replace("\\" , "/")
sheet_title = "Music Sheet Purpeech" 

# Separate notes based on duration
# You may need to customize this part to fit your specific requirements for note separation
# This is a simple example splitting the audio into equal segments
segment_duration = .5  # Duration for each note segment in seconds

# =================================================================

# os.system(f"demucs -d cpu {filename}")
name = filename.split("/")[-1].split(".")[0]
file_path = 'C:/Music2leadsheet/separated/htdemucs/{}/vocals.wav'.format(name)  # Replace with your audio file path
audio_data, sr = librosa.load(file_path, sr=None)

num_segments = int(len(audio_data) / (segment_duration * sr))

for i in range(num_segments):
    start = int(i * segment_duration * sr)
    end = int((i + 1) * segment_duration * sr)
    segment = audio_data[start:end]

    # Perform Fourier analysis to find dominant frequency
    dominant_freq = get_dom_freq(segment, sr)

    # Find the closest note based on dominant frequency
    closest_note = min(note_frequencies, key=lambda x: abs(note_frequencies[x] - dominant_freq))

    # Add data to the data structure
    data_structure.append({"duration" : segment_duration , 
                           "note" : closest_note})
    
music_sheet = generate_music_sheet(data_structure, title=sheet_title)
music_sheet.show("musicxml")

# remove folders
# shutil.rmtree(r"C:/Music2leadsheet/separated/htdemucs/{}".format(name))

for i in data_structure :
    print(i)
# Out:
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'G4'}
# {'duration': 0.5, 'note': 'G4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'D4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'D4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'G4'}
# {'duration': 0.5, 'note': 'D4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'E4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'D4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'G4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G4'}
# {'duration': 0.5, 'note': 'G4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'C4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'C#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'E4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A#3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'D#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'F4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'G#4'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A4'}
# {'duration': 0.5, 'note': 'A3'}
# {'duration': 0.5, 'note': 'A3'}

# %% [markdown]
# # Test version 2
# - fix dynamic duration

# %%
import os
import librosa
import librosa.display
import numpy as np
import shutil
from music21 import note, stream, metadata, environment

us = environment.UserSettings()
us['musicxmlPath'] = r'C://Program Files//MuseScore 4//bin//MuseScore4.exe'
us['musescoreDirectPNGPath'] = r'C://Program Files//MuseScore 4//bin//MuseScore4.exe'
us['lilypondPath'] = r'C://Music2leadsheet//lilypond-2.24.3//bin//lilypond.exe'

# =================================================================
# DEFINES
# Data structure for storing notes
data_structure = []
# Define note frequencies
note_frequencies = {
    "A3": 220.0,
    "A#3": 233.1,
    "B3": 246.9,
    "C4": 261.6,
    "C#4": 277.2,
    "D4": 293.7,
    "D#4": 311.1,
    "E4": 329.6,
    "F4": 349.2,
    "F#4": 370.0,
    "G4": 392.0,
    "G#4": 415.3,
    "A4": 440.0
}
# =================================================================

# =================================================================
# FUNCTIONS
# Function to perform Fourier analysis and find dominant frequency
def get_dom_freq(signal, sr):
    # Calculate FFT
    fft = np.fft.fft(signal)
    # Frequency corresponding to each point in FFT
    freqs = np.fft.fftfreq(len(fft), 1/sr)
    # Find index of maximum amplitude in FFT
    dom_freq_index = np.argmax(np.abs(fft))
    # Get dominant frequency
    dom_freq = freqs[dom_freq_index]
    return dom_freq

# Function to convert note names to music21 Note objects
def create_note(note_name):
    return note.Note(note_name)

# Modify the generate_music_sheet function to use onset and offset
def generate_music_sheet(data_structure, title="Generated Music Sheet"):
    # Create an empty music21 Stream
    music_stream = stream.Stream()

    # Set title for the music sheet
    music_sheet_metadata = metadata.Metadata()
    music_sheet_metadata.title = title
    music_stream.insert(0, music_sheet_metadata)

    for segment in data_structure:
        # Extract onset, offset, and note information
        onset = segment['onset']
        offset = segment['offset']
        note_name = segment['note']

        # Round the duration to the nearest quarter note
        rounded_duration = round((offset - onset) / 0.25) * 0.25

        # Create a Note object based on the note name
        n = create_note(note_name)
        # Set the onset and offset of the note
        n.offset = onset
        n.duration.quarterLength = rounded_duration
        # Add the note to the music stream
        music_stream.append(n)

    return music_stream
# =================================================================

# =================================================================

# config
# filename = input().replace("\\", "/")
sheet_title = "Music Sheet Purpeech"

# Dynamic segment_duration based on onset detection
# file_path = 'C:/Music2leadsheet/separated/htdemucs/{}/vocals.wav'.format(filename.split("/")[-1].split(".")[0])  # Replace with your audio file path
file_path = 'C:/Music2leadsheet/separated/htdemucs/TEST/vocals.wav'
audio_data, sr = librosa.load(file_path, sr=None)
# print(sr)
# Calculate onset strength
onset_env = librosa.onset.onset_strength(y=audio_data, sr=sr)
# Detect onset times
onset_times = librosa.onset.onset_detect(onset_envelope=onset_env, sr=sr)


# Use the detected onsets to determine segment_duration dynamically
if len(onset_times) >= 1:
    # Calculate the average time difference between onsets
    avg_onset_diff = np.mean(np.diff(onset_times))
    segment_duration = avg_onset_diff
else:
    # Use a default segment_duration if no onsets are detected
    segment_duration = 0.5  # You can set a default value

num_segments = int(len(audio_data) / (segment_duration * sr))

for i in range(num_segments):
    start = int(i * segment_duration * sr)
    end = int((i + 1) * segment_duration * sr)
    onset = start / sr
    offset = end / sr
    segment = audio_data[start:end]

    # Perform Fourier analysis to find dominant frequency
    dominant_freq = get_dom_freq(segment, sr)

    # Find the closest note based on dominant frequency
    closest_note = min(
        note_frequencies, key=lambda x: abs(note_frequencies[x] - dominant_freq))

    # Add data to the data structure
    data_structure.append({"onset": onset,
                           "offset": offset,
                           "note": closest_note})

music_sheet = generate_music_sheet(data_structure, title=sheet_title)
# music_sheet.show("musicxml")
music_sheet.show()

# remove folders
# shutil.rmtree(
#     r"C:/Music2leadsheet/separated/htdemucs/{}".format(filename.split("/")[-1].split(".")[0]))

for i in data_structure:
    print(i)
# Out:
# {'onset': 0.0, 'offset': 17.716961451247165, 'note': 'A3'}
# {'onset': 17.716961451247165, 'offset': 35.43392290249433, 'note': 'A#3'}
# {'onset': 35.43392290249433, 'offset': 53.150884353741496, 'note': 'A3'}
# {'onset': 53.150884353741496, 'offset': 70.86784580498866, 'note': 'A3'}
# {'onset': 70.86784580498866, 'offset': 88.58480725623583, 'note': 'A3'}
# {'onset': 88.58480725623583, 'offset': 106.30176870748299, 'note': 'A4'}
# {'onset': 106.30176870748299, 'offset': 124.01873015873016, 'note': 'A4'}
# {'onset': 124.01873015873016, 'offset': 141.73569160997732, 'note': 'G#4'}
# {'onset': 141.73569160997732, 'offset': 159.45265306122448, 'note': 'A3'}
# {'onset': 159.45265306122448, 'offset': 177.16961451247167, 'note': 'A4'}
# {'onset': 177.16961451247167, 'offset': 194.88657596371883, 'note': 'A4'}

# %% [markdown]
# # Other

# %%
import librosa
import numpy as np
from music21 import note, stream, meter, tempo

# ฟังก์ชันสำหรับอ่านไฟล์เสียง
def read_audio(file_path):
    y, sr = librosa.load(file_path)
    return y, sr

# ฟังก์ชันสำหรับคำนวณ Onset และ Offset
def calculate_onset_offset(y, sr):
    onset_frames = librosa.onset.onset_detect(y, sr=sr)
    onset_times = librosa.frames_to_time(onset_frames, sr=sr)

    offset_frames = librosa.onset.onset_detect(y, sr=sr, hop_length=512, backtrack=False)
    offset_times = librosa.frames_to_time(offset_frames, sr=sr)

    return onset_times, offset_times

# ฟังก์ชันสำหรับคำนวณความยาวของโน๊ต
def calculate_note_duration(onset, offset):
    return offset - onset

# ฟังก์ชันสำหรับทำ Fourier analysis และเลือกความถี่สูงที่สุด
def calculate_max_frequency(y, sr, onset, offset):
    start_frame = int(librosa.time_to_frames(onset, sr=sr))
    end_frame = int(librosa.time_to_frames(offset, sr=sr))
    y_segment = y[start_frame:end_frame]

    # Fast Fourier Transform (FFT)
    fft_result = np.fft.fft(y_segment)
    frequencies = np.fft.fftfreq(len(fft_result), d=1/sr)

    # เลือกความถี่ที่สูงที่สุด
    max_frequency_index = np.argmax(np.abs(fft_result))
    max_frequency = np.abs(frequencies[max_frequency_index])

    return max_frequency

# ฟังก์ชันสำหรับแปลงความถี่เป็นโน๊ต
def frequency_to_note(frequency):
    note_frequencies = {
        "A3": 220.0,
        "A#3": 233.1,
        "B3": 246.9,
        "C4": 261.6,
        "C#4": 277.2,
        "D4": 293.7,
        "D#4": 311.1,
        "E4": 329.6,
        "F4": 349.2,
        "F#4": 370.0,
        "G4": 392.0,
        "G#4": 415.3,
        "A4": 440.0
    }

    closest_note = min(note_frequencies, key=lambda x: abs(note_frequencies[x] - frequency))
    return closest_note

# ฟังก์ชันสำหรับสร้าง Music21 Stream จากข้อมูล
def create_music21_stream(data_structure):
    music_stream = stream.Score()
    part = stream.Part()

    for item in data_structure:
        if item["Duration"] > 0:
            n = note.Note(item["Note"])
            n.duration = meter.Duration(item["Duration"])
            part.append(n)

    music_stream.append(part)
    music_stream.insert(0, tempo.MetronomeMark(number=120))

    return music_stream

# ตัวอย่างการใช้งาน
file_path = r"C:\Music2leadsheet\separated\htdemucs\TEST\vocals.wav"
y, sr = read_audio(file_path)

onset_times, offset_times = calculate_onset_offset(y, sr)

data_structure = []

for i in range(len(onset_times)):
    onset = onset_times[i]
    offset = offset_times[i]
    duration = calculate_note_duration(onset, offset)
    max_frequency = calculate_max_frequency(y, sr, onset, offset)
    note_name = frequency_to_note(max_frequency)

    data_structure.append({
        "Duration": duration,
        "Note": note_name
    })

music21_stream = create_music21_stream(data_structure)
music21_stream.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Music2leadsheet\music2sheet.ipynb Cell 21 line 8
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=77'>78</a> file_path = r"C:\Music2leadsheet\separated\htdemucs\TEST\vocals.wav"
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=78'>79</a> y, sr = read_audio(file_path)
# ---> <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=80'>81</a> onset_times, offset_times = calculate_onset_offset(y, sr)
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=82'>83</a> data_structure = []
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=84'>85</a> for i in range(len(onset_times)):
#
# c:\Music2leadsheet\music2sheet.ipynb Cell 21 line 1
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=10'>11</a> def calculate_onset_offset(y, sr):
# ---> <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=11'>12</a>     onset_frames = librosa.onset.onset_detect(y, sr=sr)
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=12'>13</a>     onset_times = librosa.frames_to_time(onset_frames, sr=sr)
#      <a href='vscode-notebook-cell:/c%3A/Music2leadsheet/music2sheet.ipynb#X41sZmlsZQ%3D%3D?line=14'>15</a>     offset_frames = librosa.onset.onset_detect(y, sr=sr, hop_length=512, backtrack=False)
#
# TypeError: onset_detect() takes 0 positional arguments but 1 positional argument (and 1 keyword-only argument) were given
